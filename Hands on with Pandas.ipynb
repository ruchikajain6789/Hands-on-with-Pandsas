# %%
import pandas as pd
import numpy as np

# %%
student_df = pd.read_csv("C:/Users/Ruchika jain/OneDrive/Desktop/REDI SCHOOL/Assignment reading data from diff sources/new_students.csv")

# %%
student_df.head()
# Out:
#    id   name   lastname nationality
# 0   1  Bahar       zare        Iran
# 1   2  Bahar    Heidari        Iran
# 2   3   Tara   Anderson          UK
# 3   4   Raha      Gerde         USA
# 4   5   Anna  Jørgensen     Denmark

# %%
people_df = pd.read_excel("C:/Users/Ruchika jain/OneDrive/Desktop/REDI SCHOOL/Assignment reading data from diff sources/people_redi.xlsx")

# %%
people_df.head()
# Out:
#       name  last name   age  course_id Gender nationality  postal code  \
# 0     Tala   andersen  90.0          1      F     Denmark       2300.0
# 1     Mary      Noori   1.0          2      f         USA       1400.0
# 2      Joe      juicy  20.0          1      m         USA       2000.0
# 3      Ati    Heidari  34.0          2      f        Iran       2500.0
# 4  AmirAli  Jørgensen  19.0          1      M      France       2770.0
#
#         address   mobile number      Type
# 0  Else Alfelts        250000025  Student
# 1           NaN        542121214  Student
# 2     Nørreport  54554254254f454  Student
# 3           NaN        250005555  Student
# 4           NaN                9      NaN

# %%
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9 non-null      int64
#  1   name         9 non-null      object
#  2   lastname     8 non-null      object
#  3   nationality  9 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 416.0+ bytes

# %%
student_df.nunique()
# Out:
# id             9
# name           7
# lastname       7
# nationality    8
# dtype: int64

# %% [markdown]
# ## Sum of null values

# %%
student_df.isna().sum()
# Out:
# id             0
# name           0
# lastname       1
# nationality    0
# dtype: int64

# %%
student_df.isna().sum()[student_df.isna().sum()>0]
# Out:
# lastname    1
# dtype: int64

# %% [markdown]
# ## Calling different columns

# %%
student_df[['name','lastname']]
# Out:
#        name   lastname
# 0     Bahar       zare
# 1     Bahar    Heidari
# 2      Tara   Anderson
# 3      Raha      Gerde
# 4      Anna  Jørgensen
# 5      Anna  Jørgensen
# 6
# 7   Kashifa      Umaar
# 8  Victoria        NaN

# %%
student_df.columns
# Out:
# Index(['id', 'name', 'lastname', 'nationality'], dtype='object')

# %% [markdown]
# ## Excluding first 2 rows and last 2 rows

# %%
student_df[2:-2][['name','lastname']]
# Out:
#    name   lastname
# 2  Tara   Anderson
# 3  Raha      Gerde
# 4  Anna  Jørgensen
# 5  Anna  Jørgensen
# 6

# %% [markdown]
# ## finding duplicates

# %%
student_df[student_df.duplicated('name')]
# Out:
#    id   name   lastname nationality
# 1   2  Bahar    Heidari        Iran
# 5   6   Anna  Jørgensen     denmark

# %%
student_df[student_df.name=='Bahar']
# Out:
#    id   name lastname nationality
# 0   1  Bahar     zare        Iran
# 1   2  Bahar  Heidari        Iran

# %% [markdown]
# ## Changing column name

# %%
student_df.rename(columns={'name':'first_name'}, inplace=True)

# %%
student_df.head()
# Out:
#    id first_name   lastname nationality
# 0   1      Bahar       zare        Iran
# 1   2      Bahar    Heidari        Iran
# 2   3       Tara   Anderson          UK
# 3   4       Raha      Gerde         USA
# 4   5       Anna  Jørgensen     Denmark

# %%
student_df.rename(columns={'lastname':'Family_name'}, inplace =True)

# %%
student_df.head()
# Out:
#    id first_name Family_name nationality
# 0   1      Bahar        zare        Iran
# 1   2      Bahar     Heidari        Iran
# 2   3       Tara    Anderson          UK
# 3   4       Raha       Gerde         USA
# 4   5       Anna   Jørgensen     Denmark

# %% [markdown]
# ## dot loc and iloc

# %%
student_df.loc[:,['first_name','Family_name']] #selected columns
# Out:
#   first_name Family_name
# 0      Bahar        zare
# 1      Bahar     Heidari
# 2       Tara    Anderson
# 3       Raha       Gerde
# 4       Anna   Jørgensen
# 5       Anna   Jørgensen
# 6
# 7    Kashifa       Umaar
# 8   Victoria         NaN

# %%
student_df.loc[:,'first_name':'nationality']  #all the columns
# Out:
#   first_name Family_name nationality
# 0      Bahar        zare        Iran
# 1      Bahar     Heidari        Iran
# 2       Tara    Anderson          UK
# 3       Raha       Gerde         USA
# 4       Anna   Jørgensen     Denmark
# 5       Anna   Jørgensen     denmark
# 6
# 7    Kashifa       Umaar       India
# 8   Victoria         NaN      Ukrain

# %%
student_df.loc[1][3]
# Out:
# 'Iran'

# %%
student_df.loc[[0,1,2]]
# Out:
#    id first_name Family_name nationality
# 0   1      Bahar        zare        Iran
# 1   2      Bahar     Heidari        Iran
# 2   3       Tara    Anderson          UK

# %%
## iloc takes index row and col positon instead of index names

# %%
student_df.iloc[[0,1,2]]
# Out:
#    id first_name Family_name nationality
# 0   1      Bahar        zare        Iran
# 1   2      Bahar     Heidari        Iran
# 2   3       Tara    Anderson          UK

# %%
student_df.sort_values(by='first_name',ascending=False,inplace=True)
student_df
# Out:
#    id first_name Family_name nationality
# 8   9   Victoria         NaN      Ukrain
# 2   3       Tara    Anderson          UK
# 3   4       Raha       Gerde         USA
# 7   8    Kashifa       Umaar       India
# 0   1      Bahar        zare        Iran
# 1   2      Bahar     Heidari        Iran
# 4   5       Anna   Jørgensen     Denmark
# 5   6       Anna   Jørgensen     denmark
# 6   7

# %%
student_df.loc[3] # looks at the label of index
# Out:
# id                 4
# first_name      Raha
# Family_name    Gerde
# nationality      USA
# Name: 3, dtype: object

# %%
student_df.iloc[3] #looks at the real index(startes from 0)
# Out:
# id                   8
# first_name     Kashifa
# Family_name      Umaar
# nationality      India
# Name: 7, dtype: object

# %%
student_df.sort_values(['id','first_name'],ascending=True,inplace=True)
student_df
# Out:
#    id first_name Family_name nationality
# 0   1      Bahar        zare        Iran
# 1   2      Bahar     Heidari        Iran
# 2   3       Tara    Anderson          UK
# 3   4       Raha       Gerde         USA
# 4   5       Anna   Jørgensen     Denmark
# 5   6       Anna   Jørgensen     denmark
# 6   7
# 7   8    Kashifa       Umaar       India
# 8   9   Victoria         NaN      Ukrain

# %% [markdown]
# ## dropping duplicates

# %%
student_df[student_df.duplicated('first_name')]
# Out:
#    id first_name Family_name nationality
# 1   2      Bahar     Heidari        Iran
# 5   6       Anna   Jørgensen     denmark

# %%
student_df.drop_duplicates('first_name',keep='first',inplace=True)

# %%
student_df
# Out:
#    id first_name Family_name nationality
# 0   1      Bahar        zare        Iran
# 2   3       Tara    Anderson          UK
# 3   4       Raha       Gerde         USA
# 4   5       Anna   Jørgensen     Denmark
# 6   7
# 7   8    Kashifa       Umaar       India
# 8   9   Victoria         NaN      Ukrain

# %% [markdown]
# ## fill empty rows

# %%
student_df['first_name'].fillna('nan')  # it hs a space it is not empty
# Out:
# 0       Bahar
# 2        Tara
# 3        Raha
# 4        Anna
# 6
# 7     Kashifa
# 8    Victoria
# Name: first_name, dtype: object

# %%
student_df['first_name'].replace(" ",'karan')
# Out:
# 0       Bahar
# 2        Tara
# 3        Raha
# 4        Anna
# 6       karan
# 7     Kashifa
# 8    Victoria
# Name: first_name, dtype: object

# %% [markdown]
# ## adding new column

# %%
student_df
Hobbies=['playing','dancing']

# %%
student_df.drop(['Hobbies'],axis=1)
# Out:
#    id first_name Family_name nationality
# 0   1      Bahar        zare        Iran
# 2   3       Tara    Anderson          UK
# 3   4       Raha       Gerde         USA
# 4   5       Anna   Jørgensen     Denmark
# 6   7
# 7   8    Kashifa       Umaar       India
# 8   9   Victoria         NaN      Ukrain

# %%
hobbies =['playing','dancing','browsing','playing',' ','hiking','nothing']

# %%
student_df['Hobbies']=hobbies

# %%
student_df
# Out:
#    id first_name Family_name nationality   Hobbies
# 0   1      Bahar        zare        Iran   playing
# 2   3       Tara    Anderson          UK   dancing
# 3   4       Raha       Gerde         USA  browsing
# 4   5       Anna   Jørgensen     Denmark   playing
# 6   7
# 7   8    Kashifa       Umaar       India    hiking
# 8   9   Victoria         NaN      Ukrain   nothing

# %%
people_df
# Out:
#         name   last name   age  course_id Gender nationality  postal code  \
# 0       Tala    andersen  90.0          1      F     Denmark       2300.0
# 1       Mary       Noori   1.0          2      f         USA       1400.0
# 2        Joe       juicy  20.0          1      m         USA       2000.0
# 3        Ati     Heidari  34.0          2      f        Iran       2500.0
# 4    AmirAli   Jørgensen  19.0          1      M      France       2770.0
# 5     Jørgen      karimi  50.0          1      m     Denamrk          NaN
# 6      Bahar    shabnami   NaN          2      F      Turkey       3500.0
# 7       Raju  raju zadeh  25.0          1    NaN       India       2300.0
# 8   Ashwaria    moghadam  30.0          2      F       India       2045.0
# 9       Nana  emilderson  45.0         12      f      Sweden       5255.0
# 10      Niki      karimi  28.0          3      F          UK          NaN
# 11      Rosa     niknami  30.0          3     F         Iran       2300.0
# ...

# %%
people_df[people_df['Gender']=='F']  #fetching data with one condition
# Out:
#         name last name   age  course_id Gender nationality  postal code  \
# 0       Tala  andersen  90.0          1      F     Denmark       2300.0
# 6      Bahar  shabnami   NaN          2      F      Turkey       3500.0
# 8   Ashwaria  moghadam  30.0          2      F       India       2045.0
# 10      Niki    karimi  28.0          3      F          UK          NaN
#
#          address mobile number      Type
# 0   Else Alfelts      250000025  Student
# 6            NaN     8522222444  Student
# 8            NaN     7772222446  Student
# 10           NaN     5822222448  Student

# %%
people_df[(people_df['Gender']=='F') & (people_df['nationality']=='India')]
# Out:
#        name last name   age  course_id Gender nationality  postal code  \
# 8  Ashwaria  moghadam  30.0          2      F       India       2045.0
#
#   address mobile number      Type
# 8     NaN     7772222446  Student

# %%
people_df[(people_df['Gender']=='F') | (people_df['nationality']=='India')]
# Out:
#         name   last name   age  course_id Gender nationality  postal code  \
# 0       Tala    andersen  90.0          1      F     Denmark       2300.0
# 6      Bahar    shabnami   NaN          2      F      Turkey       3500.0
# 7       Raju  raju zadeh  25.0          1    NaN       India       2300.0
# 8   Ashwaria    moghadam  30.0          2      F       India       2045.0
# 10      Niki      karimi  28.0          3      F          UK          NaN
#
#          address mobile number      Type
# 0   Else Alfelts      250000025  Student
# 6            NaN     8522222444  Student
# 7            NaN     6662222445  Student
# 8            NaN     7772222446  Student
# 10           NaN     5822222448  Student

# %%
people_df[people_df['Gender'].isin(['F','f'])]
# Out:
#         name   last name   age  course_id Gender nationality  postal code  \
# 0       Tala    andersen  90.0          1      F     Denmark       2300.0
# 1       Mary       Noori   1.0          2      f         USA       1400.0
# 3        Ati     Heidari  34.0          2      f        Iran       2500.0
# 6      Bahar    shabnami   NaN          2      F      Turkey       3500.0
# 8   Ashwaria    moghadam  30.0          2      F       India       2045.0
# 9       Nana  emilderson  45.0         12      f      Sweden       5255.0
# 10      Niki      karimi  28.0          3      F          UK          NaN
# 12     Mette  fredriksen   NaN          2      f       Nepal       2400.0
# 13  Louretta        abdi  28.0          1      f     ukraine       4000.0
# 14      Nana  emilderson  45.0         12      f      Danish       5255.0
#
#          address mobile number      Type
# 0   Else Alfelts      250000025  Student
# 1            NaN      542121214  Student
# ...

# %%
people_df.Gender=people_df.Gender.fillna('missing').apply(lambda x : x.upper())

# %%
people_df['Gender'].apply(lambda x: x.upper())
# Out:
# 0           F
# 1           F
# 2           M
# 3           F
# 4           M
# 5           M
# 6           F
# 7     MISSING
# 8           F
# 9           F
# 10          F
# 11          F
# 12          F
# 13          F
# 14          F
# Name: Gender, dtype: object

# %%
people_df
# Out:
#         name   last name   age  course_id   Gender nationality  postal code  \
# 0       Tala    andersen  90.0          1        F     Denmark       2300.0
# 1       Mary       Noori   1.0          2        F         USA       1400.0
# 2        Joe       juicy  20.0          1        M         USA       2000.0
# 3        Ati     Heidari  34.0          2        F        Iran       2500.0
# 4    AmirAli   Jørgensen  19.0          1        M      France       2770.0
# 5     Jørgen      karimi  50.0          1        M     Denamrk          NaN
# 6      Bahar    shabnami   NaN          2        F      Turkey       3500.0
# 7       Raju  raju zadeh  25.0          1  MISSING       India       2300.0
# 8   Ashwaria    moghadam  30.0          2        F       India       2045.0
# 9       Nana  emilderson  45.0         12        F      Sweden       5255.0
# 10      Niki      karimi  28.0          3        F          UK          NaN
# ...

# %%
people_df.groupby('Type').agg({'age':['min','max','mean']})
# Out:
#           age
#           min   max  mean
# Type
# Student   1.0  90.0  36.0
# Teacher  30.0  30.0  30.0
